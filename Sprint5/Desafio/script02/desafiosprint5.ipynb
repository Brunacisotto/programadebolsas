# %%
import boto3
import pandas as pd

session = boto3.Session(profile_name='AdministratorAccess-794038242332')

s3 = session.client('s3')

# %%
# Parâmetros do download
bucket_name = 'desafio-sprint5'  
s3_key = 'uploads/dadosogu.csv' 
local_file_path = 'C:/Users/sidci/OneDrive/Documentos/Bruna/compass/sprint5/dadosogu_baixado.csv'

try:
    s3.download_file(Bucket=bucket_name, Key=s3_key, Filename=local_file_path)
    print("Arquivo baixado com sucesso!")
except Exception as e:
    print("Erro ao baixar o arquivo:", e)
# Out:
# Arquivo baixado com sucesso!

# %%
dadosgov = pd.read_csv('dadosogu_baixado.csv', sep='|', dtype={19: object})

# %%
dadosgov
# Out:
#       data_referencia  cod_ibge txt_nome_municipio txt_sigla_uf txt_regiao  \
# 0          30/09/2024    110.02       Porto Velho            RO      Norte
# 1          30/09/2024    110.02       Porto Velho            RO      Norte
# 2          30/09/2024    110.02       Porto Velho            RO      Norte
# 3          30/09/2024    110.02       Porto Velho            RO      Norte
# 4          30/09/2024    110.02       Porto Velho            RO      Norte
# ...               ...       ...                ...          ...        ...
# 58341      30/09/2024    311.06            Cambuí            MG    Sudeste
# 58342      30/09/2024    260.41           Caruaru            PE   Nordeste
# 58343      30/09/2024    231.29            Sobral            CE   Nordeste
# 58344      30/09/2024    431.49      Porto Alegre            RS        Sul
# 58345      30/09/2024    280.74    Tobias Barreto            SE   Nordeste
#
#       dt_assinatura  cod_operacao  \
# 0        09/04/2010    29925581.0
# 1        09/04/2010    30011639.0
# 2        09/07/2010    32680414.0
# 3        09/07/2010    32703630.0
# 4        25/06/2013    40267126.0
# ...             ...           ...
# 58341    27/04/2018    49099583.0
# 58342    02/07/2024    63191186.0
# 58343    02/08/2024    63241600.0
# 58344    27/09/2013    53367100.0
# 58345    06/08/2024    63217932.0
#
#                                  txt_nome_empreendimento  \
# 0                        RESIDENCIAL CIDADE DE TODOS III
# 1                         RESIDENCIAL CIDADE DE TODOS IX
# 2                  RESIDENCIAL CIDADE DE TODOS - LOTE 01
# 3                  RESIDENCIAL CIDADE DE TODOS - LOTE 02
# 4                             RESIDENCIAL PORTO BELLO II
# ...                                                  ...
# 58341                                        PNHR CAMBUI
# 58342  RESIDENCIAL NOVA BARAUNA I                    ...
# 58343  RESIDENCIAL JARDINS DA SERRA II               ...
# 58344      CONDOMINIO JARDIM DAS FIGUEIRAS III - FASE II
# 58345  RESIDENCIAL AGRIPINO BERNARDO DOS SANTOS IV   ...
#
#       txt_nome_agente_financeiro txt_modalidade  ... qtd_uh  qtd_uh_entregues  \
# 0                          CAIXA            FAR  ...  240.0             240.0
# 1                          CAIXA            FAR  ...  240.0             240.0
# 2                          CAIXA            FAR  ...  114.0             114.0
# 3                          CAIXA            FAR  ...   82.0              82.0
# 4                          CAIXA            FAR  ...  272.0             272.0
# ...                          ...            ...  ...    ...               ...
# 58341                      CAIXA          Rural  ...    7.0               0.0
# 58342                      CAIXA            FAR  ...  240.0               0.0
# 58343                      CAIXA            FAR  ...  192.0               0.0
# 58344                      CAIXA      Entidades  ...  360.0             360.0
# 58345                      CAIXA            FAR  ...  100.0               0.0
#
#        qtd_uh_vigentes  qtd_uh_distratadas  val_contratado_total  \
# 0                  0.0                   0            13.830.963
# 1                  0.0                   0            14.218.052
# 2                  0.0                   0             6.840.691
# 3                  0.0                   0             3.421.062
# 4                  0.0                   0            18.161.056
# ...                ...                 ...                   ...
# 58341              0.0                   7               256.900
# 58342            240.0                   0            40.260.000
# 58343            192.0                   0         30.559.649,53
# 58344              0.0                   0            30.852.862
# 58345            100.0                   0            13.000.000
#
#       val_desembolsado txt_cnpj_construtora_entidade  \
# 0        13.809.147,96                  3.445271e+13
# 1        14.218.051,93                  3.445271e+13
# 2          6.840.691,6                  2.364225e+12
# 3         3.421.062,22                  2.364225e+12
# 4        18.161.056,68                  7.757862e+13
# ...                ...                           ...
# 58341           38.535                           NaN
# 58342                0                           NaN
# 58343                0                           NaN
# 58344       30.852.862                  5.948440e+12
# 58345                0                           NaN
#
#                            txt_nome_construtora_entidade  \
# 0                               COMERCIO ENGENHARIA LTDA
# 1                               COMERCIO ENGENHARIA LTDA
# 2                         CONSTRUTORA JOAO DE BARRO LTDA
# 3                         CONSTRUTORA JOAO DE BARRO LTDA
# 4            CASAALTA CONSTRUCOES E EMPREENDIMENTO LTDA.
# ...                                                  ...
# 58341                                                NaN
# 58342                                                NaN
# 58343                                                NaN
# 58344  INSTITUTO DE PLANEJAMENTO E ESTUDO SOCIO-AMBIE...
# 58345                                                NaN
#
#                                             txt_endereco     txt_cep
# 0               AV AMAZONAS, N� 9680 - BAIRRO SOCIALISTA  76800000.0
# 1                  RUA OSWALDO RIBEIRO, S/N - SOCIALISTA  76800000.0
# 2                                 AV AMAZONAS - LOTE 738  76800000.0
# 3                            RUA MANE GARRICHA, LOTE 393  76800000.0
# 4      RUA DE ACESSO,(ATUAL JOSE FAID), S/N BAIRRO JD...  76800000.0
# ...                                                  ...         ...
# 58341                                                NaN         NaN
# 58342                                                NaN         NaN
# 58343                                                NaN         NaN
# 58344                                                NaN         NaN
# 58345                                                NaN         NaN
#
# [58346 rows x 21 columns]

# %%
dadosgov.shape
# Out:
# (58346, 21)

# %%
dadosgov = dadosgov.drop_duplicates() ##apagar duplicadas

# %%
dadosgov.shape
# Out:
# (18151, 21)

# %%
dadosgov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18151 entries, 0 to 58345
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   data_referencia                18151 non-null  object
#  1   cod_ibge                       18151 non-null  float64
#  2   txt_nome_municipio             18151 non-null  object
#  3   txt_sigla_uf                   18151 non-null  object
#  4   txt_regiao                     18137 non-null  object
#  5   dt_assinatura                  18151 non-null  object
#  6   cod_operacao                   13585 non-null  float64
#  7   txt_nome_empreendimento        18151 non-null  object
#  8   txt_nome_agente_financeiro     18151 non-null  object
#  9   txt_modalidade                 18151 non-null  object
#  10  txt_situacao_empreendimento    18151 non-null  object
#  11  qtd_uh                         18151 non-null  float64
#  12  qtd_uh_entregues               18150 non-null  float64
#  13  qtd_uh_vigentes                18151 non-null  float64
#  14  qtd_uh_distratadas             18151 non-null  int64
#  15  val_contratado_total           18151 non-null  object
#  16  val_desembolsado               18150 non-null  object
#  17  txt_cnpj_construtora_entidade  13417 non-null  float64
#  18  txt_nome_construtora_entidade  13426 non-null  object
#  19  txt_endereco                   4067 non-null   object
#  20  txt_cep                        4067 non-null   float64
# dtypes: float64(7), int64(1), object(13)
# memory usage: 3.0+ MB

# %%
dadosgov.nunique ()
# Out:
# data_referencia                      1
# cod_ibge                          4610
# txt_nome_municipio                4414
# txt_sigla_uf                        27
# txt_regiao                           5
# dt_assinatura                     1785
# cod_operacao                     13583
# txt_nome_empreendimento          15649
# txt_nome_agente_financeiro          25
# txt_modalidade                       4
# txt_situacao_empreendimento          3
# qtd_uh                             730
# qtd_uh_entregues                   713
# qtd_uh_vigentes                    228
# qtd_uh_distratadas                  69
# val_contratado_total              6952
# val_desembolsado                  6586
# txt_cnpj_construtora_entidade     2953
# txt_nome_construtora_entidade     2943
# txt_endereco                      3524
# txt_cep                           1747
# dtype: int64

# %%
dadosgov.isnull().sum()
# Out:
# data_referencia                      0
# cod_ibge                             0
# txt_nome_municipio                   0
# txt_sigla_uf                         0
# txt_regiao                          14
# dt_assinatura                        0
# cod_operacao                      4566
# txt_nome_empreendimento              0
# txt_nome_agente_financeiro           0
# txt_modalidade                       0
# txt_situacao_empreendimento          0
# qtd_uh                               0
# qtd_uh_entregues                     1
# qtd_uh_vigentes                      0
# qtd_uh_distratadas                   0
# val_contratado_total                 0
# val_desembolsado                     1
# txt_cnpj_construtora_entidade     4734
# txt_nome_construtora_entidade     4725
# txt_endereco                     14084
# txt_cep                          14084
# dtype: int64

# %%
dadosgov[dadosgov.txt_regiao.isnull()]
# Out:
#       data_referencia  cod_ibge   txt_nome_municipio txt_sigla_uf txt_regiao  \
# 58188      30/09/2024   270.630  PALMEIRA DOS INDIOS           AL        NaN
# 58193      30/09/2024   291.080     FEIRA DE SANTANA           BA        NaN
# 58213      30/09/2024   270.630  PALMEIRA DOS INDIOS           AL        NaN
# 58215      30/09/2024   210.900         PORTO FRANCO           MA        NaN
# 58216      30/09/2024   330.630        VOLTA REDONDA           RJ        NaN
# 58233      30/09/2024   353.080           MOGI MIRIM           SP        NaN
# 58274      30/09/2024   172.100               PALMAS           TO        NaN
# 58278      30/09/2024   353.390              OLIMPIA           SP        NaN
# 58289      30/09/2024   250.750          JOAO PESSOA           PB        NaN
# 58296      30/09/2024   291.005          DIAS DAVILA           BA        NaN
# 58308      30/09/2024   353.730            PENAPOLIS           SP        NaN
# 58312      30/09/2024   270.630  PALMEIRA DOS INDIOS           AL        NaN
# 58330      30/09/2024   290.570             CAMACARI           BA        NaN
# 58332      30/09/2024   290.570             CAMACARI           BA        NaN
#
#       dt_assinatura  cod_operacao  \
# 58188    17/07/2024    62769362.0
# 58193    11/07/2024    62678003.0
# 58213    17/07/2024    62769476.0
# 58215    29/07/2024    63144086.0
# 58216    04/07/2024    62768232.0
# 58233    26/07/2024    63396684.0
# 58274    02/07/2024    63107453.0
# 58278    05/07/2024    63239773.0
# 58289    02/07/2024    61507208.0
# 58296    19/07/2024    63091057.0
# 58308    02/08/2024    62914563.0
# 58312    17/07/2024    62769258.0
# 58330    19/07/2024    62743758.0
# 58332    19/07/2024    62743976.0
#
#                                  txt_nome_empreendimento  \
# 58188  RESIDENCIAL JULIA JOSEFA DE JESUS             ...
# 58193  RESIDENCIAL RIO DE JANEIRO II                 ...
# 58213  RESIDENCIAL PREFEITO GILENO COSTA SAMPAIO     ...
# 58215  JARDIM PORTO FRANCO II                        ...
# 58216  RESIDENCIAL THEREZINHA GONCALVES              ...
# 58233  CONJUNTO HABITACIONAL MANERA                  ...
# 58274  CONDOMINIO RESIDENCIAL PARQUE DOS IPES III    ...
# 58278  RESIDENCIAL OLIMPIA F                         ...
# 58289  RESIDENCIAL DO S                              ...
# 58296  RESIDENCIAL VILA CONCORDIA I                  ...
# 58308  RESIDENCIAL MUNDO NOVO IV                     ...
# 58312  RESIDENCIAL EURIDES NASCIMENTO TAVARES        ...
# 58330  VERDES HORIZONTES I                           ...
# 58332  VERDES HORIZONTES II                          ...
#
#       txt_nome_agente_financeiro txt_modalidade  ... qtd_uh  qtd_uh_entregues  \
# 58188                      CAIXA            FAR  ...  150.0               0.0
# 58193                      CAIXA            FAR  ...  226.0               0.0
# 58213                      CAIXA            FAR  ...  100.0               0.0
# 58215                      CAIXA            FAR  ...   50.0               0.0
# 58216                      CAIXA            FAR  ...  112.0               0.0
# 58233                      CAIXA            FAR  ...  100.0               0.0
# 58274                      CAIXA            FAR  ...  128.0               0.0
# 58278                      CAIXA            FAR  ...  150.0               0.0
# 58289                      CAIXA            FAR  ...  192.0               0.0
# 58296                      CAIXA            FAR  ...  148.0               0.0
# 58308                      CAIXA            FAR  ...   96.0               0.0
# 58312                      CAIXA            FAR  ...  150.0               0.0
# 58330                      CAIXA            FAR  ...  192.0               0.0
# 58332                      CAIXA            FAR  ...  192.0               0.0
#
#        qtd_uh_vigentes  qtd_uh_distratadas  val_contratado_total  \
# 58188            150.0                   0            21.450.000
# 58193            226.0                   0            34.679.700
# 58213            100.0                   0            14.300.000
# 58215             50.0                   0          7.149.414,71
# 58216            112.0                   0            17.877.000
# 58233            100.0                   0         16.865.286,51
# 58274            128.0                   0            21.472.000
# 58278            150.0                   0         23.455.901,48
# 58289            192.0                   0         32.570.144,96
# 58296            148.0                   0            21.830.000
# 58308             96.0                   0         15.489.564,14
# 58312            150.0                   0            21.450.000
# 58330            192.0                   0            32.524.800
# 58332            192.0                   0            32.524.800
#
#       val_desembolsado txt_cnpj_construtora_entidade  \
# 58188                0                           NaN
# 58193                0                           NaN
# 58213                0                           NaN
# 58215                0                           NaN
# 58216                0                           NaN
# 58233                0                           NaN
# 58274                0                           NaN
# 58278                0                           NaN
# 58289                0                           NaN
# 58296                0                           NaN
# 58308                0                           NaN
# 58312                0                           NaN
# 58330                0                           NaN
# 58332                0                           NaN
#
#        txt_nome_construtora_entidade txt_endereco txt_cep
# 58188                            NaN          NaN     NaN
# 58193                            NaN          NaN     NaN
# 58213                            NaN          NaN     NaN
# 58215                            NaN          NaN     NaN
# 58216                            NaN          NaN     NaN
# 58233                            NaN          NaN     NaN
# 58274                            NaN          NaN     NaN
# 58278                            NaN          NaN     NaN
# 58289                            NaN          NaN     NaN
# 58296                            NaN          NaN     NaN
# 58308                            NaN          NaN     NaN
# 58312                            NaN          NaN     NaN
# 58330                            NaN          NaN     NaN
# 58332                            NaN          NaN     NaN
#
# [14 rows x 21 columns]

# %%
estado_para_regiao = {
    'AC': 'Norte', 'AL': 'Nordeste', 'AP': 'Norte', 'AM': 'Norte',
    'BA': 'Nordeste', 'CE': 'Nordeste', 'DF': 'Centro-Oeste', 'ES': 'Sudeste',
    'GO': 'Centro-Oeste', 'MA': 'Nordeste', 'MT': 'Centro-Oeste', 'MS': 'Centro-Oeste',
    'MG': 'Sudeste', 'PA': 'Norte', 'PB': 'Nordeste', 'PR': 'Sul',
    'PE': 'Nordeste', 'PI': 'Nordeste', 'RJ': 'Sudeste', 'RN': 'Nordeste',
    'RS': 'Sul', 'RO': 'Norte', 'RR': 'Norte', 'SC': 'Sul',
    'SP': 'Sudeste', 'SE': 'Nordeste', 'TO': 'Norte'
}
dadosgov.loc[dadosgov['txt_regiao'].isna(), 'txt_regiao'] = dadosgov['txt_sigla_uf'].map(estado_para_regiao)

# %%
dadosgov[dadosgov.txt_regiao.isnull()]
# Out:
# Empty DataFrame
# Columns: [data_referencia, cod_ibge, txt_nome_municipio, txt_sigla_uf, txt_regiao, dt_assinatura, cod_operacao, txt_nome_empreendimento, txt_nome_agente_financeiro, txt_modalidade, txt_situacao_empreendimento, qtd_uh, qtd_uh_entregues, qtd_uh_vigentes, qtd_uh_distratadas, val_contratado_total, val_desembolsado, txt_cnpj_construtora_entidade, txt_nome_construtora_entidade, txt_endereco, txt_cep]
# Index: []
#
# [0 rows x 21 columns]

# %%
dadosgov[dadosgov.val_desembolsado.isnull()]
# Out:
#       data_referencia  cod_ibge       txt_nome_municipio txt_sigla_uf  \
# 16193      30/09/2024    110.07  Campo Novo de Rondônia            RO
#
#       txt_regiao dt_assinatura  cod_operacao txt_nome_empreendimento  \
# 16193      Norte    30/06/2016     1747317.0     1627-ALTAMIRA-12-RO
#
#       txt_nome_agente_financeiro txt_modalidade  ... qtd_uh  qtd_uh_entregues  \
# 16193                         BB          Rural  ...    4.0               0.0
#
#        qtd_uh_vigentes  qtd_uh_distratadas  val_contratado_total  \
# 16193              4.0                   0               126.000
#
#       val_desembolsado txt_cnpj_construtora_entidade  \
# 16193              NaN                  5.888813e+12
#
#                            txt_nome_construtora_entidade txt_endereco txt_cep
# 16193  ENTIDADE AUTARQUICA DE ASSIST TECN E EXTE RURA...          NaN     NaN
#
# [1 rows x 21 columns]

# %%
dadosgov.loc[dadosgov['val_desembolsado'].isna(), 'val_desembolsado'] = 0

# %%
dadosgov[dadosgov.val_desembolsado.isnull()]
# Out:
# Empty DataFrame
# Columns: [data_referencia, cod_ibge, txt_nome_municipio, txt_sigla_uf, txt_regiao, dt_assinatura, cod_operacao, txt_nome_empreendimento, txt_nome_agente_financeiro, txt_modalidade, txt_situacao_empreendimento, qtd_uh, qtd_uh_entregues, qtd_uh_vigentes, qtd_uh_distratadas, val_contratado_total, val_desembolsado, txt_cnpj_construtora_entidade, txt_nome_construtora_entidade, txt_endereco, txt_cep]
# Index: []
#
# [0 rows x 21 columns]

# %%
dadosgov[dadosgov.qtd_uh_entregues.isnull()]
# Out:
#       data_referencia  cod_ibge txt_nome_municipio txt_sigla_uf txt_regiao  \
# 19617      30/09/2024    355.03         São Paulo            SP    Sudeste
#
#       dt_assinatura  cod_operacao txt_nome_empreendimento  \
# 19617    04/09/2015    45707347.0    COPA DO POVO GLEBA B
#
#       txt_nome_agente_financeiro txt_modalidade  ... qtd_uh  qtd_uh_entregues  \
# 19617                      CAIXA      Entidades  ...  648.0               NaN
#
#        qtd_uh_vigentes  qtd_uh_distratadas  val_contratado_total  \
# 19617            648.0                   0            15.205.558
#
#       val_desembolsado txt_cnpj_construtora_entidade  \
# 19617                0                  7.367387e+12
#
#                            txt_nome_construtora_entidade  \
# 19617  ASS DE MORADORES DO ACAMPAMENTO ESPERANCA DE U...
#
#                                             txt_endereco    txt_cep
# 19617  RUA ISOSUKE OKAVE X RUA MALMEQUER DO CAMPO S/N...  8270700.0
#
# [1 rows x 21 columns]

# %%
dadosgov.loc[dadosgov.qtd_uh_entregues.isnull(), 'qtd_uh_entregues'] = 0.0

# %%
dadosgov[dadosgov.qtd_uh_entregues.isnull()]
# Out:
# Empty DataFrame
# Columns: [data_referencia, cod_ibge, txt_nome_municipio, txt_sigla_uf, txt_regiao, dt_assinatura, cod_operacao, txt_nome_empreendimento, txt_nome_agente_financeiro, txt_modalidade, txt_situacao_empreendimento, qtd_uh, qtd_uh_entregues, qtd_uh_vigentes, qtd_uh_distratadas, val_contratado_total, val_desembolsado, txt_cnpj_construtora_entidade, txt_nome_construtora_entidade, txt_endereco, txt_cep]
# Index: []
#
# [0 rows x 21 columns]

# %%
dadosgov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18151 entries, 0 to 58345
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   data_referencia                18151 non-null  object
#  1   cod_ibge                       18151 non-null  float64
#  2   txt_nome_municipio             18151 non-null  object
#  3   txt_sigla_uf                   18151 non-null  object
#  4   txt_regiao                     18151 non-null  object
#  5   dt_assinatura                  18151 non-null  object
#  6   cod_operacao                   13585 non-null  float64
#  7   txt_nome_empreendimento        18151 non-null  object
#  8   txt_nome_agente_financeiro     18151 non-null  object
#  9   txt_modalidade                 18151 non-null  object
#  10  txt_situacao_empreendimento    18151 non-null  object
#  11  qtd_uh                         18151 non-null  float64
#  12  qtd_uh_entregues               18151 non-null  float64
#  13  qtd_uh_vigentes                18151 non-null  float64
#  14  qtd_uh_distratadas             18151 non-null  int64
#  15  val_contratado_total           18151 non-null  object
#  16  val_desembolsado               18151 non-null  object
#  17  txt_cnpj_construtora_entidade  13417 non-null  float64
#  18  txt_nome_construtora_entidade  13426 non-null  object
#  19  txt_endereco                   4067 non-null   object
#  20  txt_cep                        4067 non-null   float64
# dtypes: float64(7), int64(1), object(13)
# memory usage: 3.6+ MB

# %%
dadosgov['data_referencia'].nunique()
# Out:
# 1

# %%
colunas_remover = [
    'data_referencia',
    'txt_cnpj_construtora_entidade',
    'txt_nome_construtora_entidade',
    'txt_endereco',
    'txt_cep'
]
dadosgov = dadosgov.drop(columns=colunas_remover)

# %%
dadosgov.head(3)
# Out:
#    cod_ibge txt_nome_municipio txt_sigla_uf txt_regiao dt_assinatura  \
# 0    110.02       Porto Velho            RO      Norte    09/04/2010
# 1    110.02       Porto Velho            RO      Norte    09/04/2010
# 2    110.02       Porto Velho            RO      Norte    09/07/2010
#
#    cod_operacao                txt_nome_empreendimento  \
# 0    29925581.0        RESIDENCIAL CIDADE DE TODOS III
# 1    30011639.0         RESIDENCIAL CIDADE DE TODOS IX
# 2    32680414.0  RESIDENCIAL CIDADE DE TODOS - LOTE 01
#
#   txt_nome_agente_financeiro txt_modalidade txt_situacao_empreendimento  \
# 0                      CAIXA            FAR                   Concluído
# 1                      CAIXA            FAR                   Concluído
# 2                      CAIXA            FAR                   Concluído
#
#    qtd_uh  qtd_uh_entregues  qtd_uh_vigentes  qtd_uh_distratadas  \
# 0   240.0             240.0              0.0                   0
# 1   240.0             240.0              0.0                   0
# 2   114.0             114.0              0.0                   0
#
#   val_contratado_total val_desembolsado
# 0           13.830.963    13.809.147,96
# 1           14.218.052    14.218.051,93
# 2            6.840.691      6.840.691,6

# %%
dadosgov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18151 entries, 0 to 58345
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cod_ibge                     18151 non-null  float64
#  1   txt_nome_municipio           18151 non-null  object
#  2   txt_sigla_uf                 18151 non-null  object
#  3   txt_regiao                   18151 non-null  object
#  4   dt_assinatura                18151 non-null  object
#  5   cod_operacao                 13585 non-null  float64
#  6   txt_nome_empreendimento      18151 non-null  object
#  7   txt_nome_agente_financeiro   18151 non-null  object
#  8   txt_modalidade               18151 non-null  object
#  9   txt_situacao_empreendimento  18151 non-null  object
#  10  qtd_uh                       18151 non-null  float64
#  11  qtd_uh_entregues             18151 non-null  float64
#  12  qtd_uh_vigentes              18151 non-null  float64
#  13  qtd_uh_distratadas           18151 non-null  int64
#  14  val_contratado_total         18151 non-null  object
#  15  val_desembolsado             18151 non-null  object
# dtypes: float64(5), int64(1), object(10)
# memory usage: 2.9+ MB

# %%
dadosgov
# Out:
#        cod_ibge txt_nome_municipio txt_sigla_uf txt_regiao dt_assinatura  \
# 0        110.02       Porto Velho            RO      Norte    09/04/2010
# 1        110.02       Porto Velho            RO      Norte    09/04/2010
# 2        110.02       Porto Velho            RO      Norte    09/07/2010
# 3        110.02       Porto Velho            RO      Norte    09/07/2010
# 4        110.02       Porto Velho            RO      Norte    25/06/2013
# ...         ...                ...          ...        ...           ...
# 58341    311.06            Cambuí            MG    Sudeste    27/04/2018
# 58342    260.41           Caruaru            PE   Nordeste    02/07/2024
# 58343    231.29            Sobral            CE   Nordeste    02/08/2024
# 58344    431.49      Porto Alegre            RS        Sul    27/09/2013
# 58345    280.74    Tobias Barreto            SE   Nordeste    06/08/2024
#
#        cod_operacao                            txt_nome_empreendimento  \
# 0        29925581.0                    RESIDENCIAL CIDADE DE TODOS III
# 1        30011639.0                     RESIDENCIAL CIDADE DE TODOS IX
# 2        32680414.0              RESIDENCIAL CIDADE DE TODOS - LOTE 01
# 3        32703630.0              RESIDENCIAL CIDADE DE TODOS - LOTE 02
# 4        40267126.0                         RESIDENCIAL PORTO BELLO II
# ...             ...                                                ...
# 58341    49099583.0                                        PNHR CAMBUI
# 58342    63191186.0  RESIDENCIAL NOVA BARAUNA I                    ...
# 58343    63241600.0  RESIDENCIAL JARDINS DA SERRA II               ...
# 58344    53367100.0      CONDOMINIO JARDIM DAS FIGUEIRAS III - FASE II
# 58345    63217932.0  RESIDENCIAL AGRIPINO BERNARDO DOS SANTOS IV   ...
#
#       txt_nome_agente_financeiro txt_modalidade txt_situacao_empreendimento  \
# 0                          CAIXA            FAR                   Concluído
# 1                          CAIXA            FAR                   Concluído
# 2                          CAIXA            FAR                   Concluído
# 3                          CAIXA            FAR                   Concluído
# 4                          CAIXA            FAR                   Concluído
# ...                          ...            ...                         ...
# 58341                      CAIXA          Rural        Distratado/Cancelado
# 58342                      CAIXA            FAR               Não Concluído
# 58343                      CAIXA            FAR               Não Concluído
# 58344                      CAIXA      Entidades                   Concluído
# 58345                      CAIXA            FAR               Não Concluído
#
#        qtd_uh  qtd_uh_entregues  qtd_uh_vigentes  qtd_uh_distratadas  \
# 0       240.0             240.0              0.0                   0
# 1       240.0             240.0              0.0                   0
# 2       114.0             114.0              0.0                   0
# 3        82.0              82.0              0.0                   0
# 4       272.0             272.0              0.0                   0
# ...       ...               ...              ...                 ...
# 58341     7.0               0.0              0.0                   7
# 58342   240.0               0.0            240.0                   0
# 58343   192.0               0.0            192.0                   0
# 58344   360.0             360.0              0.0                   0
# 58345   100.0               0.0            100.0                   0
#
#       val_contratado_total val_desembolsado
# 0               13.830.963    13.809.147,96
# 1               14.218.052    14.218.051,93
# 2                6.840.691      6.840.691,6
# 3                3.421.062     3.421.062,22
# 4               18.161.056    18.161.056,68
# ...                    ...              ...
# 58341              256.900           38.535
# 58342           40.260.000                0
# 58343        30.559.649,53                0
# 58344           30.852.862       30.852.862
# 58345           13.000.000                0
#
# [18151 rows x 16 columns]

# %%
dadosgov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18151 entries, 0 to 58345
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cod_ibge                     18151 non-null  float64
#  1   txt_nome_municipio           18151 non-null  object
#  2   txt_sigla_uf                 18151 non-null  object
#  3   txt_regiao                   18151 non-null  object
#  4   dt_assinatura                18151 non-null  object
#  5   cod_operacao                 13585 non-null  float64
#  6   txt_nome_empreendimento      18151 non-null  object
#  7   txt_nome_agente_financeiro   18151 non-null  object
#  8   txt_modalidade               18151 non-null  object
#  9   txt_situacao_empreendimento  18151 non-null  object
#  10  qtd_uh                       18151 non-null  float64
#  11  qtd_uh_entregues             18151 non-null  float64
#  12  qtd_uh_vigentes              18151 non-null  float64
#  13  qtd_uh_distratadas           18151 non-null  int64
#  14  val_contratado_total         18151 non-null  object
#  15  val_desembolsado             18151 non-null  object
# dtypes: float64(5), int64(1), object(10)
# memory usage: 2.9+ MB

# %%
dadosgov['qtd_uh'] = dadosgov['qtd_uh'].astype(int)

# %%
dadosgov['qtd_uh_vigentes'] = dadosgov['qtd_uh_vigentes'].astype(int)

# %%
dadosgov['qtd_uh_entregues'] = dadosgov['qtd_uh_entregues'].astype(float).astype(int)

# %%
dadosgov['val_desembolsado'] = (dadosgov['val_desembolsado']
    .str.replace('.', '', regex=False) 
    .str.replace(',', '.', regex=False)  
    .astype(float))

# %%
dadosgov['val_contratado_total'] = (
    dadosgov['val_contratado_total']
    .str.replace('.', '', regex=False) 
    .str.replace(',', '.', regex=False)  
    .astype(float))

# %%
dadosgov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18151 entries, 0 to 58345
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cod_ibge                     18151 non-null  float64
#  1   txt_nome_municipio           18151 non-null  object
#  2   txt_sigla_uf                 18151 non-null  object
#  3   txt_regiao                   18151 non-null  object
#  4   dt_assinatura                18151 non-null  object
#  5   cod_operacao                 13585 non-null  float64
#  6   txt_nome_empreendimento      18151 non-null  object
#  7   txt_nome_agente_financeiro   18151 non-null  object
#  8   txt_modalidade               18151 non-null  object
#  9   txt_situacao_empreendimento  18151 non-null  object
#  10  qtd_uh                       18151 non-null  int32
#  11  qtd_uh_entregues             18151 non-null  int32
#  12  qtd_uh_vigentes              18151 non-null  int32
#  13  qtd_uh_distratadas           18151 non-null  int64
#  14  val_contratado_total         18151 non-null  float64
#  15  val_desembolsado             18150 non-null  float64
# dtypes: float64(4), int32(3), int64(1), object(8)
# memory usage: 2.7+ MB

# %%
dadosgov.to_csv('dadosok.csv')

# %%
bucket_name = 'desafio-sprint5'
file_path = "C:\\Users\\sidci\\OneDrive\\Documentos\\Bruna\\compass\\sprint5\\dadosok.csv"
s3_key = 'uploads/dadosogutratado.csv'

try:
    s3.upload_file(Filename=file_path, Bucket=bucket_name, Key=s3_key)
    print("Arquivo enviado com sucesso para o S3!")
except Exception as e:
    print("Erro ao enviar o arquivo:", e)
# Out:
# Arquivo enviado com sucesso para o S3!
