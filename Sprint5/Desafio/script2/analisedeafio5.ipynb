# %%
import boto3
import pandas as pd
import re

session = boto3.Session(profile_name='AdministratorAccess-794038242332')

s3 = session.client('s3')

# %%
# Parâmetros do download
bucket_name = 'desafio-sprint5'  
s3_key = 'uploads/dadosogutratado.csv' 
local_file_path = 'C:/Users/sidci/OneDrive/Documentos/Bruna/compass/dadosok.csv'

try:
    s3.download_file(Bucket=bucket_name, Key=s3_key, Filename=local_file_path)
    print("Arquivo baixado com sucesso!")
except Exception as e:
    print("Erro ao baixar o arquivo:", e)
# Out:
# Arquivo baixado com sucesso!

# %% [markdown]
# A pergunta a ser respondida nessa analise é:
# No ano de 2018, quais foram as 10 cidades da região SUL, que mais tiveram imóveis concluídos e entregues subsidiados pela OGU , por intermedio de bancos públicos?

# %%
dadosanalise = pd.read_csv ('dadosok.csv')

# %%
dadosanalise
# Out:
#        Unnamed: 0  cod_ibge txt_nome_municipio txt_sigla_uf txt_regiao  \
# 0               0    110.02       Porto Velho            RO      Norte
# 1               1    110.02       Porto Velho            RO      Norte
# 2               2    110.02       Porto Velho            RO      Norte
# 3               3    110.02       Porto Velho            RO      Norte
# 4               4    110.02       Porto Velho            RO      Norte
# ...           ...       ...                ...          ...        ...
# 18146       58341    311.06            Cambuí            MG    Sudeste
# 18147       58342    260.41           Caruaru            PE   Nordeste
# 18148       58343    231.29            Sobral            CE   Nordeste
# 18149       58344    431.49      Porto Alegre            RS        Sul
# 18150       58345    280.74    Tobias Barreto            SE   Nordeste
#
#       dt_assinatura  cod_operacao  \
# 0        09/04/2010    29925581.0
# 1        09/04/2010    30011639.0
# 2        09/07/2010    32680414.0
# 3        09/07/2010    32703630.0
# 4        25/06/2013    40267126.0
# ...             ...           ...
# 18146    27/04/2018    49099583.0
# 18147    02/07/2024    63191186.0
# 18148    02/08/2024    63241600.0
# 18149    27/09/2013    53367100.0
# 18150    06/08/2024    63217932.0
#
#                                  txt_nome_empreendimento  \
# 0                        RESIDENCIAL CIDADE DE TODOS III
# 1                         RESIDENCIAL CIDADE DE TODOS IX
# 2                  RESIDENCIAL CIDADE DE TODOS - LOTE 01
# 3                  RESIDENCIAL CIDADE DE TODOS - LOTE 02
# 4                             RESIDENCIAL PORTO BELLO II
# ...                                                  ...
# 18146                                        PNHR CAMBUI
# 18147  RESIDENCIAL NOVA BARAUNA I                    ...
# 18148  RESIDENCIAL JARDINS DA SERRA II               ...
# 18149      CONDOMINIO JARDIM DAS FIGUEIRAS III - FASE II
# 18150  RESIDENCIAL AGRIPINO BERNARDO DOS SANTOS IV   ...
#
#       txt_nome_agente_financeiro txt_modalidade txt_situacao_empreendimento  \
# 0                          CAIXA            FAR                   Concluído
# 1                          CAIXA            FAR                   Concluído
# 2                          CAIXA            FAR                   Concluído
# 3                          CAIXA            FAR                   Concluído
# 4                          CAIXA            FAR                   Concluído
# ...                          ...            ...                         ...
# 18146                      CAIXA          Rural        Distratado/Cancelado
# 18147                      CAIXA            FAR               Não Concluído
# 18148                      CAIXA            FAR               Não Concluído
# 18149                      CAIXA      Entidades                   Concluído
# 18150                      CAIXA            FAR               Não Concluído
#
#        qtd_uh  qtd_uh_entregues  qtd_uh_vigentes  qtd_uh_distratadas  \
# 0         240               240                0                   0
# 1         240               240                0                   0
# 2         114               114                0                   0
# 3          82                82                0                   0
# 4         272               272                0                   0
# ...       ...               ...              ...                 ...
# 18146       7                 0                0                   7
# 18147     240                 0              240                   0
# 18148     192                 0              192                   0
# 18149     360               360                0                   0
# 18150     100                 0              100                   0
#
#        val_contratado_total  val_desembolsado
# 0               13830963.00       13809147.96
# 1               14218052.00       14218051.93
# 2                6840691.00        6840691.60
# 3                3421062.00        3421062.22
# 4               18161056.00       18161056.68
# ...                     ...               ...
# 18146             256900.00          38535.00
# 18147           40260000.00              0.00
# 18148           30559649.53              0.00
# 18149           30852862.00       30852862.00
# 18150           13000000.00              0.00
#
# [18151 rows x 17 columns]

# %%
dadosanalise.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18151 entries, 0 to 18150
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   18151 non-null  int64
#  1   cod_ibge                     18151 non-null  float64
#  2   txt_nome_municipio           18151 non-null  object
#  3   txt_sigla_uf                 18151 non-null  object
#  4   txt_regiao                   18151 non-null  object
#  5   dt_assinatura                18151 non-null  object
#  6   cod_operacao                 13585 non-null  float64
#  7   txt_nome_empreendimento      18151 non-null  object
#  8   txt_nome_agente_financeiro   18151 non-null  object
#  9   txt_modalidade               18151 non-null  object
#  10  txt_situacao_empreendimento  18151 non-null  object
#  11  qtd_uh                       18151 non-null  int64
#  12  qtd_uh_entregues             18151 non-null  int64
#  13  qtd_uh_vigentes              18151 non-null  int64
#  14  qtd_uh_distratadas           18151 non-null  int64
#  15  val_contratado_total         18151 non-null  float64
#  16  val_desembolsado             18150 non-null  float64
# dtypes: float64(4), int64(5), object(8)
# memory usage: 2.4+ MB

# %% [markdown]
# Uma função de conversão (convertendo o campo dt_assinatura para formato datetime)

# %%
dadosanalise['dt_assinatura'] = pd.to_datetime(dadosanalise['dt_assinatura'], format='%d/%m/%Y')

# %%
dadosanalise.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18151 entries, 0 to 18150
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   18151 non-null  int64
#  1   cod_ibge                     18151 non-null  float64
#  2   txt_nome_municipio           18151 non-null  object
#  3   txt_sigla_uf                 18151 non-null  object
#  4   txt_regiao                   18151 non-null  object
#  5   dt_assinatura                18151 non-null  datetime64[ns]
#  6   cod_operacao                 13585 non-null  float64
#  7   txt_nome_empreendimento      18151 non-null  object
#  8   txt_nome_agente_financeiro   18151 non-null  object
#  9   txt_modalidade               18151 non-null  object
#  10  txt_situacao_empreendimento  18151 non-null  object
#  11  qtd_uh                       18151 non-null  int64
#  12  qtd_uh_entregues             18151 non-null  int64
#  13  qtd_uh_vigentes              18151 non-null  int64
#  14  qtd_uh_distratadas           18151 non-null  int64
#  15  val_contratado_total         18151 non-null  float64
#  16  val_desembolsado             18150 non-null  float64
#  17  ano_assinatura               18151 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(5), object(7)
# memory usage: 2.4+ MB

# %% [markdown]
# Uma função de String (convertendo para Maiusculas o campo txt_nome_municipio, txt_regiao, txt_nome_agente_financeiro)

# %%
dadosanalise[['txt_nome_municipio', 'txt_regiao', 'txt_nome_agente_financeiro']] = \
dadosanalise[['txt_nome_municipio', 'txt_regiao', 'txt_nome_agente_financeiro']].apply(lambda col: col.str.upper())

# %%
dadosanalise
# Out:
#        Unnamed: 0  cod_ibge txt_nome_municipio txt_sigla_uf txt_regiao  \
# 0               0    110.02       PORTO VELHO            RO      NORTE
# 1               1    110.02       PORTO VELHO            RO      NORTE
# 2               2    110.02       PORTO VELHO            RO      NORTE
# 3               3    110.02       PORTO VELHO            RO      NORTE
# 4               4    110.02       PORTO VELHO            RO      NORTE
# ...           ...       ...                ...          ...        ...
# 18146       58341    311.06            CAMBUÍ            MG    SUDESTE
# 18147       58342    260.41           CARUARU            PE   NORDESTE
# 18148       58343    231.29            SOBRAL            CE   NORDESTE
# 18149       58344    431.49      PORTO ALEGRE            RS        SUL
# 18150       58345    280.74    TOBIAS BARRETO            SE   NORDESTE
#
#       dt_assinatura  cod_operacao  \
# 0        2010-04-09    29925581.0
# 1        2010-04-09    30011639.0
# 2        2010-07-09    32680414.0
# 3        2010-07-09    32703630.0
# 4        2013-06-25    40267126.0
# ...             ...           ...
# 18146    2018-04-27    49099583.0
# 18147    2024-07-02    63191186.0
# 18148    2024-08-02    63241600.0
# 18149    2013-09-27    53367100.0
# 18150    2024-08-06    63217932.0
#
#                                  txt_nome_empreendimento  \
# 0                        RESIDENCIAL CIDADE DE TODOS III
# 1                         RESIDENCIAL CIDADE DE TODOS IX
# 2                  RESIDENCIAL CIDADE DE TODOS - LOTE 01
# 3                  RESIDENCIAL CIDADE DE TODOS - LOTE 02
# 4                             RESIDENCIAL PORTO BELLO II
# ...                                                  ...
# 18146                                        PNHR CAMBUI
# 18147  RESIDENCIAL NOVA BARAUNA I                    ...
# 18148  RESIDENCIAL JARDINS DA SERRA II               ...
# 18149      CONDOMINIO JARDIM DAS FIGUEIRAS III - FASE II
# 18150  RESIDENCIAL AGRIPINO BERNARDO DOS SANTOS IV   ...
#
#       txt_nome_agente_financeiro txt_modalidade txt_situacao_empreendimento  \
# 0                          CAIXA            FAR                   Concluído
# 1                          CAIXA            FAR                   Concluído
# 2                          CAIXA            FAR                   Concluído
# 3                          CAIXA            FAR                   Concluído
# 4                          CAIXA            FAR                   Concluído
# ...                          ...            ...                         ...
# 18146                      CAIXA          Rural        Distratado/Cancelado
# 18147                      CAIXA            FAR               Não Concluído
# 18148                      CAIXA            FAR               Não Concluído
# 18149                      CAIXA      Entidades                   Concluído
# 18150                      CAIXA            FAR               Não Concluído
#
#        qtd_uh  qtd_uh_entregues  qtd_uh_vigentes  qtd_uh_distratadas  \
# 0         240               240                0                   0
# 1         240               240                0                   0
# 2         114               114                0                   0
# 3          82                82                0                   0
# 4         272               272                0                   0
# ...       ...               ...              ...                 ...
# 18146       7                 0                0                   7
# 18147     240                 0              240                   0
# 18148     192                 0              192                   0
# 18149     360               360                0                   0
# 18150     100                 0              100                   0
#
#        val_contratado_total  val_desembolsado  ano_assinatura
# 0               13830963.00       13809147.96            2010
# 1               14218052.00       14218051.93            2010
# 2                6840691.00        6840691.60            2010
# 3                3421062.00        3421062.22            2010
# 4               18161056.00       18161056.68            2013
# ...                     ...               ...             ...
# 18146             256900.00          38535.00            2018
# 18147           40260000.00              0.00            2024
# 18148           30559649.53              0.00            2024
# 18149           30852862.00       30852862.00            2013
# 18150           13000000.00              0.00            2024
#
# [18151 rows x 18 columns]

# %%
Função de data isolando apenas o

# %%
dadosanalise['ano_assinatura'] = dadosanalise['dt_assinatura'].dt.year
df_2018 = dadosanalise[dadosanalise['ano_assinatura'] == 2018]

# %%
df_2018
# Out:
#        Unnamed: 0  cod_ibge     txt_nome_municipio txt_sigla_uf txt_regiao  \
# 22             22   220.700                OEIRAS            PI   NORDESTE
# 51             51   160.030                MACAPÁ            AP      NORTE
# 52             52   160.030                MACAPÁ            AP      NORTE
# 83             83   130.260                MANAUS            AM      NORTE
# 84             84   130.260                MANAUS            AM      NORTE
# ...           ...       ...                    ...          ...        ...
# 17985       58180   250.750           JOÃO PESSOA            PB   NORDESTE
# 17986       58181   412.385  SANTA MARIA DO OESTE            PR        SUL
# 18051       58246   260.130    BARRA DE GUABIRABA            PE   NORDESTE
# 18060       58255   250.750           JOÃO PESSOA            PB   NORDESTE
# 18146       58341   311.060                CAMBUÍ            MG    SUDESTE
#
#       dt_assinatura  cod_operacao              txt_nome_empreendimento  \
# 22       2018-07-30    50506923.0                   ALTO DAS CANELA II
# 51       2018-02-07    49473844.0                       VILA OPERARIOS
# 52       2018-06-07    49560352.0                       VILA OPERARIOS
# 83       2018-01-30    48934594.0  RESIDENCIAL CIDADAO MANAUARA II - A
# 84       2018-10-11    48936212.0  RESIDENCIAL CIDADAO MANAUARA II - B
# ...             ...           ...                                  ...
# 17985    2018-11-21    39010030.0             CONDOMINIO RES. CANAA II
# 17986    2018-04-27    48811713.0   CAPRICHANDO A MORADA STA M D OESTE
# 18051    2018-04-27    49233754.0                 BARRA DE GUABIRABA I
# 18060    2018-11-21    39010020.0              CONDOMINIO RES. CANAA I
# 18146    2018-04-27    49099583.0                          PNHR CAMBUI
#
#       txt_nome_agente_financeiro txt_modalidade txt_situacao_empreendimento  \
# 22                         CAIXA            FAR                   Concluído
# 51                         CAIXA            FAR               Não Concluído
# 52                         CAIXA            FAR               Não Concluído
# 83                         CAIXA            FAR                   Concluído
# 84                         CAIXA            FAR                   Concluído
# ...                          ...            ...                         ...
# 17985                         BB            FAR                   Concluído
# 17986                      CAIXA          Rural        Distratado/Cancelado
# 18051                      CAIXA          Rural        Distratado/Cancelado
# 18060                         BB            FAR                   Concluído
# 18146                      CAIXA          Rural        Distratado/Cancelado
#
#        qtd_uh  qtd_uh_entregues  qtd_uh_vigentes  qtd_uh_distratadas  \
# 22         12                12                0                   0
# 51        224                 0              224                   0
# 52        276                 0              276                   0
# 83        500               500                0                   0
# 84        500               500                0                   0
# ...       ...               ...              ...                 ...
# 17985     480               480                0                   0
# 17986      11                 0                0                  11
# 18051      16                 0                0                  16
# 18060     480               480                0                   0
# 18146       7                 0                0                   7
#
#        val_contratado_total  val_desembolsado  ano_assinatura
# 22                 780000.0         780000.00            2018
# 51               21504000.0       11849809.19            2018
# 52               26496000.0       13849511.13            2018
# 83               41438189.0       41438189.09            2018
# 84               41000000.0       41000000.00            2018
# ...                     ...               ...             ...
# 17985            41923965.0       37045920.00            2018
# 17986              555550.0         376200.00            2018
# 18051              547200.0          82080.00            2018
# 18060            41642308.0       36365064.00            2018
# 18146              256900.0          38535.00            2018
#
# [1237 rows x 18 columns]

# %% [markdown]
# Função de condicional para txt_situacao_do_empreendimento, por condicionando á "Concluído"

# %%
df_2018.loc[:,'concluido'] = df_2018['txt_situacao_empreendimento'].apply(lambda x: True if x == 'Concluído' else False)
df_concluidos = df_2018[df_2018['concluido']]

# %%
df_concluidos
# Out:
#        Unnamed: 0  cod_ibge txt_nome_municipio txt_sigla_uf txt_regiao  \
# 22             22   220.700            OEIRAS            PI   NORDESTE
# 83             83   130.260            MANAUS            AM      NORTE
# 84             84   130.260            MANAUS            AM      NORTE
# 112           112   150.140             BELÉM            PA      NORTE
# 113           113   150.140             BELÉM            PA      NORTE
# ...           ...       ...                ...          ...        ...
# 13394       29442   420.517        ENTRE RIOS            SC        SUL
# 13395       29443   420.517        ENTRE RIOS            SC        SUL
# 13396       29444   420.517        ENTRE RIOS            SC        SUL
# 17985       58180   250.750       JOÃO PESSOA            PB   NORDESTE
# 18060       58255   250.750       JOÃO PESSOA            PB   NORDESTE
#
#       dt_assinatura  cod_operacao              txt_nome_empreendimento  \
# 22       2018-07-30    50506923.0                   ALTO DAS CANELA II
# 83       2018-01-30    48934594.0  RESIDENCIAL CIDADAO MANAUARA II - A
# 84       2018-10-11    48936212.0  RESIDENCIAL CIDADAO MANAUARA II - B
# 112      2018-07-17    49320696.0     RESIDENCIAL VIVER MARACACUERA II
# 113      2018-07-17    49322299.0      RESIDENCIAL VIVER MARACACUERA I
# ...             ...           ...                                  ...
# 13394    2018-04-27    48680163.0                      PNHR ENTRE RIOS
# 13395    2018-04-27    48671957.0                      PNHR ENTRE RIOS
# 13396    2018-04-27    48679697.0                PNHR ENTRE RIOS 17 UH
# 17985    2018-11-21    39010030.0             CONDOMINIO RES. CANAA II
# 18060    2018-11-21    39010020.0              CONDOMINIO RES. CANAA I
#
#       txt_nome_agente_financeiro txt_modalidade txt_situacao_empreendimento  \
# 22                         CAIXA            FAR                   Concluído
# 83                         CAIXA            FAR                   Concluído
# 84                         CAIXA            FAR                   Concluído
# 112                        CAIXA            FAR                   Concluído
# 113                        CAIXA            FAR                   Concluído
# ...                          ...            ...                         ...
# 13394                      CAIXA          Rural                   Concluído
# 13395                      CAIXA          Rural                   Concluído
# 13396                      CAIXA          Rural                   Concluído
# 17985                         BB            FAR                   Concluído
# 18060                         BB            FAR                   Concluído
#
#        qtd_uh  qtd_uh_entregues  qtd_uh_vigentes  qtd_uh_distratadas  \
# 22         12                12                0                   0
# 83        500               500                0                   0
# 84        500               500                0                   0
# 112       480               480                0                   0
# 113       480               480                0                   0
# ...       ...               ...              ...                 ...
# 13394      12                12                0                   0
# 13395      16                16                0                   0
# 13396      17                17                0                   0
# 17985     480               480                0                   0
# 18060     480               480                0                   0
#
#        val_contratado_total  val_desembolsado  ano_assinatura  concluido
# 22                 780000.0         780000.00            2018       True
# 83               41438189.0       41438189.09            2018       True
# 84               41000000.0       41000000.00            2018       True
# 112              40130762.0       40130761.52            2018       True
# 113              39791897.0       39791897.78            2018       True
# ...                     ...               ...             ...        ...
# 13394              582672.0         410400.00            2018       True
# 13395              776896.0         547200.00            2018       True
# 13396              825452.0         581400.00            2018       True
# 17985            41923965.0       37045920.00            2018       True
# 18060            41642308.0       36365064.00            2018       True
#
# [1008 rows x 19 columns]

# %%
filtro de dados, com dois operadores lógicos, para bancos públicos (BB e CAIXA) e região SUL

# %%
filtrologico = ((df_concluidos['txt_nome_agente_financeiro'] == 'CAIXA') | 
                (df_concluidos['txt_nome_agente_financeiro'] == 'BB')) & \
                (df_concluidos['txt_regiao'] == 'SUL')

# %%
df_filtrado = df_concluidos[filtrologico]

# %%
df_filtrado
# Out:
#        Unnamed: 0  cod_ibge txt_nome_municipio txt_sigla_uf txt_regiao  \
# 2665         2665   410.420       CAMPO LARGO            PR        SUL
# 2692         2692   410.830     FOZ DO IGUAÇU            PR        SUL
# 2693         2693   410.830     FOZ DO IGUAÇU            PR        SUL
# 2694         2694   410.830     FOZ DO IGUAÇU            PR        SUL
# 2715         2715   411.140              IVAÍ            PR        SUL
# ...           ...       ...                ...          ...        ...
# 13330       29378   411.910              PIÊN            PR        SUL
# 13342       29390   410.420       CAMPO LARGO            PR        SUL
# 13394       29442   420.517        ENTRE RIOS            SC        SUL
# 13395       29443   420.517        ENTRE RIOS            SC        SUL
# 13396       29444   420.517        ENTRE RIOS            SC        SUL
#
#       dt_assinatura  cod_operacao               txt_nome_empreendimento  \
# 2665     2018-02-07    48898858.0            CAMPO LARGO I. RESIDENCIAL
# 2692     2018-05-28    49226152.0                  RESIDENCIAL ANGATUBA
# 2693     2018-11-13    51242914.0                      CONDOMINIO BOICY
# 2694     2018-11-13    51243157.0                   CONDOMINIO BOICY II
# 2715     2018-02-07    49897396.0                 LOTEAMENTO PALMITAL I
# ...             ...           ...                                   ...
# 13330    2018-04-27    48793711.0       AGRICULT GI: CONSTR - PNHR PIEN
# 13342    2018-04-27    48788714.0  MORADIAS RURAIS CAMPO L - QUILOMBOLA
# 13394    2018-04-27    48680163.0                       PNHR ENTRE RIOS
# 13395    2018-04-27    48671957.0                       PNHR ENTRE RIOS
# 13396    2018-04-27    48679697.0                 PNHR ENTRE RIOS 17 UH
#
#       txt_nome_agente_financeiro txt_modalidade txt_situacao_empreendimento  \
# 2665                       CAIXA            FAR                   Concluído
# 2692                       CAIXA            FAR                   Concluído
# 2693                       CAIXA            FAR                   Concluído
# 2694                       CAIXA            FAR                   Concluído
# 2715                       CAIXA            FAR                   Concluído
# ...                          ...            ...                         ...
# 13330                      CAIXA          Rural                   Concluído
# 13342                      CAIXA          Rural                   Concluído
# 13394                      CAIXA          Rural                   Concluído
# 13395                      CAIXA          Rural                   Concluído
# 13396                      CAIXA          Rural                   Concluído
#
#        qtd_uh  qtd_uh_entregues  qtd_uh_vigentes  qtd_uh_distratadas  \
# 2665      416               416                0                   0
# 2692      340               340                0                   0
# 2693      288               288                0                   0
# 2694      288               288                0                   0
# 2715       47                47                0                   0
# ...       ...               ...              ...                 ...
# 13330      10                10                0                   0
# 13342      14                14                0                   0
# 13394      12                12                0                   0
# 13395      16                16                0                   0
# 13396      17                17                0                   0
#
#        val_contratado_total  val_desembolsado  ano_assinatura  concluido
# 2665             34112000.0       34112000.00            2018       True
# 2692             27200000.0       27200000.00            2018       True
# 2693             23040000.0       23040000.00            2018       True
# 2694             23040000.0       23040000.00            2018       True
# 2715              3377562.0        3377562.12            2018       True
# ...                     ...               ...             ...        ...
# 13330              342000.0         342000.00            2018       True
# 13342              478800.0         478800.00            2018       True
# 13394              582672.0         410400.00            2018       True
# 13395              776896.0         547200.00            2018       True
# 13396              825452.0         581400.00            2018       True
#
# [124 rows x 19 columns]

# %% [markdown]
# ao menos 2 funçoes de agregação (groupby e sum)

# %%
df_resultado = df_filtrado.groupby(['txt_nome_municipio']).agg({
    'qtd_uh_entregues': 'sum',            
    'val_desembolsado': 'sum',  
     'txt_sigla_uf': 'first',    
   }).sort_values('qtd_uh_entregues', ascending=False)  # Ordena pela soma de qtd_uh_entregues

# %%
df_resultado.head(10)
# Out:
#                     qtd_uh_entregues  val_desembolsado txt_sigla_uf
# txt_nome_municipio
# FOZ DO IGUAÇU                    916       73280000.00           PR
# SANTA CRUZ DO SUL                563       35871343.00           RS
# CANOAS                           500       41000000.00           RS
# CAMPO LARGO                      430       34590800.00           PR
# NOVO HAMBURGO                    305       24990000.00           RS
# CURITIBANOS                      300       21095446.61           SC
# SANTA MARIANA                    283       19385354.29           PR
# SÃO BENTO DO SUL                 244       18497723.68           SC
# JAGUARIAÍVA                      200       14372689.99           PR
# CARAMBEÍ                         154       12054408.20           PR

# %%
df_analise = df_resultado.head(10)

# %%
df_analise.to_csv('analisecidades.csv')

# %%
bucket_name = 'desafio-sprint5'
file_path = "C:\\Users\\sidci\\OneDrive\\Documentos\\Bruna\\compass\\sprint5\\analisecidades.csv"
s3_key = 'uploads/analisecidades.csv'

try:
    s3.upload_file(Filename=file_path, Bucket=bucket_name, Key=s3_key)
    print("Arquivo enviado com sucesso para o S3!")
except Exception as e:
    print("Erro ao enviar o arquivo:", e)
# Out:
# Arquivo enviado com sucesso para o S3!
